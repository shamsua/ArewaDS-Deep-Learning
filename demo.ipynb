# %% [markdown]
# # Demo - Time Series Forecasting with TabPFN  🎉
#
# Welcome to the demo of TabPFN for time series forecasting!
#
# In this demo, we will show you how to use TabPFN for time series forecasting. Concretely, we will:
#
# 1. **Load time series data** -- you can also bring in time series data from your own problem
# 2. **Add features** -- we will use default features, but feel free to experiment with your own features!
# 3. **Perform prediction** -- zero-shot! 😉
# 4. **Visualize the forecasting results**

# %% [markdown]
# ## Setup

# %%
# !pip install tabpfn-time-series

# for downloading datasets
# !pip install datasets
# Out:
# Requirement already satisfied: tabpfn-time-series in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (0.1.1)
# Requirement already satisfied: autogluon-timeseries==1.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-time-series) (1.2)
# Requirement already satisfied: gluonts==0.16.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-time-series) (0.16.0)
# Requirement already satisfied: pandas in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-time-series) (2.2.3)
# Requirement already satisfied: tabpfn-client==0.1.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-time-series) (0.1.1)
# Requirement already satisfied: tabpfn==2.0.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-time-series) (2.0.0)
# Requirement already satisfied: tqdm in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-time-series) (4.67.1)
# Requirement already satisfied: joblib<2,>=1.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (1.4.2)
# Requirement already satisfied: numpy<2.1.4,>=1.25.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (1.26.4)
# Requirement already satisfied: scipy<1.16,>=1.5.4 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (1.15.0)
# Requirement already satisfied: torch<2.6,>=2.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (2.5.1)
# Requirement already satisfied: lightning<2.6,>=2.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (2.5.0.post0)
# Requirement already satisfied: pytorch-lightning in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (2.5.0.post0)
# Requirement already satisfied: transformers<5,>=4.38.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from transformers[sentencepiece]<5,>=4.38.0->autogluon-timeseries==1.2->tabpfn-time-series) (4.47.1)
# Requirement already satisfied: accelerate<1.0,>=0.34.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (0.34.2)
# Requirement already satisfied: networkx<4,>=3.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (3.4.2)
# Requirement already satisfied: statsforecast<1.8,>=1.7.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (1.7.8)
# Requirement already satisfied: mlforecast==0.13.4 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (0.13.4)
# Requirement already satisfied: utilsforecast<0.2.5,>=0.2.3 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (0.2.4)
# Requirement already satisfied: coreforecast==0.0.12 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (0.0.12)
# Requirement already satisfied: fugue>=0.9.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (0.9.1)
# Requirement already satisfied: orjson~=3.9 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (3.10.13)
# Requirement already satisfied: tensorboard<3,>=2.9 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (2.18.0)
# Requirement already satisfied: autogluon.core==1.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.2)
# Requirement already satisfied: autogluon.common==1.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon-timeseries==1.2->tabpfn-time-series) (1.2)
# Requirement already satisfied: autogluon.tabular==1.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.2)
# Requirement already satisfied: pydantic<3,>=1.7 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from gluonts==0.16.0->tabpfn-time-series) (2.10.4)
# Requirement already satisfied: toolz~=0.10 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from gluonts==0.16.0->tabpfn-time-series) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from gluonts==0.16.0->tabpfn-time-series) (4.12.2)
# Requirement already satisfied: scikit-learn>=1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn==2.0.0->tabpfn-time-series) (1.5.2)
# Requirement already satisfied: einops in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn==2.0.0->tabpfn-time-series) (0.8.0)
# Requirement already satisfied: huggingface-hub in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn==2.0.0->tabpfn-time-series) (0.27.1)
# Requirement already satisfied: cityhash<=0.4.7,>=0.4.3 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-client==0.1.1->tabpfn-time-series) (0.4.7)
# Requirement already satisfied: httpx<=0.27.2,>=0.25.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-client==0.1.1->tabpfn-time-series) (0.27.2)
# Requirement already satisfied: omegaconf<=2.3.0,>=2.1.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-client==0.1.1->tabpfn-time-series) (2.3.0)
# Requirement already satisfied: password-strength<=0.0.3.post2,>=0.0.3.post2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-client==0.1.1->tabpfn-time-series) (0.0.3.post2)
# Requirement already satisfied: sseclient-py<=1.8.0,>=1.8.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tabpfn-client==0.1.1->tabpfn-time-series) (1.8.0)
# Requirement already satisfied: boto3<2,>=1.10 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.common==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.35.94)
# Requirement already satisfied: psutil<7.0.0,>=5.7.3 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.common==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (6.1.1)
# Requirement already satisfied: requests in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (2.32.3)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (3.10.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (18.1.0)
# Requirement already satisfied: ray<2.40,>=2.10.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (2.39.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.2.7)
# Requirement already satisfied: autogluon.features==1.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.tabular==1.2->autogluon.tabular[catboost,lightgbm,xgboost]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.2)
# Requirement already satisfied: lightgbm<4.6,>=4.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (4.5.0)
# Requirement already satisfied: catboost<1.3,>=1.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.2.7)
# Requirement already satisfied: xgboost<2.2,>=1.6 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (2.1.3)
# Requirement already satisfied: cloudpickle in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (3.1.0)
# Requirement already satisfied: fsspec in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (2024.9.0)
# Requirement already satisfied: numba in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (0.60.0)
# Requirement already satisfied: optuna in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (4.1.0)
# Requirement already satisfied: packaging in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (24.2)
# Requirement already satisfied: window-ops in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (0.0.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from pandas->tabpfn-time-series) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from pandas->tabpfn-time-series) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from pandas->tabpfn-time-series) (2024.2)
# Requirement already satisfied: pyyaml in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from accelerate<1.0,>=0.34.0->autogluon-timeseries==1.2->tabpfn-time-series) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from accelerate<1.0,>=0.34.0->autogluon-timeseries==1.2->tabpfn-time-series) (0.5.1)
# Requirement already satisfied: triad>=0.9.7 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from fugue>=0.9.0->autogluon-timeseries==1.2->tabpfn-time-series) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from fugue>=0.9.0->autogluon-timeseries==1.2->tabpfn-time-series) (0.2.6)
# Requirement already satisfied: anyio in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from httpx<=0.27.2,>=0.25.0->tabpfn-client==0.1.1->tabpfn-time-series) (4.8.0)
# Requirement already satisfied: certifi in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from httpx<=0.27.2,>=0.25.0->tabpfn-client==0.1.1->tabpfn-time-series) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from httpx<=0.27.2,>=0.25.0->tabpfn-client==0.1.1->tabpfn-time-series) (1.0.7)
# Requirement already satisfied: idna in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from httpx<=0.27.2,>=0.25.0->tabpfn-client==0.1.1->tabpfn-time-series) (3.10)
# Requirement already satisfied: sniffio in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from httpx<=0.27.2,>=0.25.0->tabpfn-client==0.1.1->tabpfn-time-series) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from httpcore==1.*->httpx<=0.27.2,>=0.25.0->tabpfn-client==0.1.1->tabpfn-time-series) (0.14.0)
# Requirement already satisfied: filelock in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from huggingface-hub->tabpfn==2.0.0->tabpfn-time-series) (3.16.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from lightning<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.11.9)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from lightning<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.6.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from omegaconf<=2.3.0,>=2.1.2->tabpfn-client==0.1.1->tabpfn-time-series) (4.9.3)
# Requirement already satisfied: six in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from password-strength<=0.0.3.post2,>=0.0.3.post2->tabpfn-client==0.1.1->tabpfn-time-series) (1.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from pydantic<3,>=1.7->gluonts==0.16.0->tabpfn-time-series) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from pydantic<3,>=1.7->gluonts==0.16.0->tabpfn-time-series) (2.27.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from scikit-learn>=1->tabpfn==2.0.0->tabpfn-time-series) (3.5.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from statsforecast<1.8,>=1.7.0->autogluon-timeseries==1.2->tabpfn-time-series) (0.14.4)
# Requirement already satisfied: absl-py>=0.4 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon-timeseries==1.2->tabpfn-time-series) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon-timeseries==1.2->tabpfn-time-series) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon-timeseries==1.2->tabpfn-time-series) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon-timeseries==1.2->tabpfn-time-series) (5.29.2)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon-timeseries==1.2->tabpfn-time-series) (75.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon-timeseries==1.2->tabpfn-time-series) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon-timeseries==1.2->tabpfn-time-series) (3.1.3)
# Requirement already satisfied: jinja2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from torch<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from torch<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from sympy==1.13.1->torch<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from transformers<5,>=4.38.0->transformers[sentencepiece]<5,>=4.38.0->autogluon-timeseries==1.2->tabpfn-time-series) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from transformers<5,>=4.38.0->transformers[sentencepiece]<5,>=4.38.0->autogluon-timeseries==1.2->tabpfn-time-series) (0.21.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from transformers[sentencepiece]<5,>=4.38.0->autogluon-timeseries==1.2->tabpfn-time-series) (0.2.0)
# Requirement already satisfied: botocore<1.36.0,>=1.35.94 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.common==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.35.94)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.common==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.common==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.10.4)
# Requirement already satisfied: graphviz in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from catboost<1.3,>=1.2->autogluon.tabular[catboost,lightgbm,xgboost]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.20.3)
# Requirement already satisfied: plotly in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from catboost<1.3,>=1.2->autogluon.tabular[catboost,lightgbm,xgboost]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (5.24.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (3.11.11)
# Requirement already satisfied: future in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.0.0)
# Requirement already satisfied: py4j in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.10.9.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (3.2.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from numba->mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (0.43.0)
# Requirement already satisfied: click>=7.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (8.1.8)
# Requirement already satisfied: jsonschema in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.1.0)
# Requirement already satisfied: aiosignal in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.3.2)
# Requirement already satisfied: frozenlist in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.5.0)
# Requirement already satisfied: tensorboardX>=1.9 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (2.6.2.2)
# Requirement already satisfied: aiohttp-cors in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.7.0)
# Requirement already satisfied: colorful in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.4.0)
# Requirement already satisfied: opencensus in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.11.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.21.1)
# Requirement already satisfied: smart-open in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (20.28.1)
# Requirement already satisfied: memray in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.15.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from statsmodels>=0.13.2->statsforecast<1.8,>=1.7.0->autogluon-timeseries==1.2->tabpfn-time-series) (1.0.1)
# Requirement already satisfied: fs in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from triad>=0.9.7->fugue>=0.9.0->autogluon-timeseries==1.2->tabpfn-time-series) (2.4.16)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<3,>=2.9->autogluon-timeseries==1.2->tabpfn-time-series) (3.0.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from anyio->httpx<=0.27.2,>=0.25.0->tabpfn-client==0.1.1->tabpfn-time-series) (1.2.2)
# Requirement already satisfied: alembic>=1.5.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from optuna->mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (1.14.0)
# Requirement already satisfied: colorlog in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from optuna->mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from optuna->mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (2.0.36)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from requests->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from requests->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (2.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (2.4.4)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<2.6,>=2.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.18.3)
# Requirement already satisfied: Mako in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from alembic>=1.5.0->optuna->mlforecast==0.13.4->autogluon-timeseries==1.2->tabpfn-time-series) (1.3.8)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (4.3.6)
# Requirement already satisfied: appdirs~=1.4.3 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from fs->triad>=0.9.7->fugue>=0.9.0->autogluon-timeseries==1.2->tabpfn-time-series) (1.4.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from jsonschema->ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from jsonschema->ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from jsonschema->ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.22.3)
# Requirement already satisfied: rich>=11.2.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (13.9.4)
# Requirement already satisfied: textual>=0.41.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.0.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (2.24.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from plotly->catboost<1.3,>=1.2->autogluon.tabular[catboost,lightgbm,xgboost]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (9.0.0)
# Requirement already satisfied: wrapt in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from smart-open->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (2.37.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from rich>=11.2.0->memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from rich>=11.2.0->memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (2.19.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (4.9)
# Requirement already satisfied: mdurl~=0.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.2.0->memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.4.2)
# Requirement already satisfied: uc-micro-py in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (1.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon-timeseries==1.2->tabpfn-time-series) (0.6.1)
# Requirement already satisfied: datasets in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (3.2.0)
# Requirement already satisfied: filelock in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/shibinhoo/miniconda3/envs/tabpfn-ts-pub/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# ## Load Time Series Data
#
# In this demo, we will use the time series dataset from [Chronos Dataset](https://huggingface.co/datasets/autogluon/chronos_datasets) on HuggingFace. Also, we'll keep it short and work with just 2 time series from the dataset.
#
# Feel free to explore other datasets by using the dataset names from Chronos Dataset on HuggingFace or even use time series data of your own problem.

# %%
dataset_metadata = {
    "monash_tourism_monthly": {"prediction_length": 24},
    "m4_hourly": {"prediction_length": 48},
}

dataset_choice = "monash_tourism_monthly"
num_time_series_subset = 2

# %%
from datasets import load_dataset
from autogluon.timeseries import TimeSeriesDataFrame

from tabpfn_time_series.data_preparation import to_gluonts_univariate, generate_test_X

prediction_length = dataset_metadata[dataset_choice]['prediction_length']
dataset = load_dataset("autogluon/chronos_datasets", dataset_choice)

tsdf = TimeSeriesDataFrame(to_gluonts_univariate(dataset['train']))
tsdf = tsdf[tsdf.index.get_level_values('item_id').isin(tsdf.item_ids[:num_time_series_subset])]
train_tsdf, test_tsdf_ground_truth = tsdf.train_test_split(prediction_length=prediction_length)
test_tsdf = generate_test_X(train_tsdf, prediction_length)

# %% [markdown]
# Let's take a look at the time series data.

# %%
from tabpfn_time_series.plot import plot_actual_ts

plot_actual_ts(train_tsdf, test_tsdf_ground_truth)

# %% [markdown]
# ## Adding Features
#
# In our paper, we propose adding `running_index` and `calendar_features` to the table.
#
# **Feel free to experiment with your own features!**
#
# To do that, simply define your own feature functions and pass them to the `FeatureTransformer`.

# %%
from tabpfn_time_series import FeatureTransformer, DefaultFeatures

selected_features = [
    DefaultFeatures.add_running_index,
    DefaultFeatures.add_calendar_features,
]

train_tsdf, test_tsdf = FeatureTransformer.add_features(
    train_tsdf, test_tsdf, selected_features
)

# %% [markdown]
# Let's take a look at the tables (train and test) before we proceed to do predictions.
#
# ✅ Realize that we have added some features into the tables.

# %%
train_tsdf.head()
# Out:
#                        target  running_index  year  hour_of_day_sin  \
# item_id timestamp
# 0       1979-01-31  1149.8700              0  1979              0.0
#         1979-02-28  1053.8002              1  1979              0.0
#         1979-03-31  1388.8798              2  1979              0.0
#         1979-04-30  1783.3702              3  1979              0.0
#         1979-05-31  1921.0252              4  1979              0.0
#
#                     hour_of_day_cos  day_of_week_sin  day_of_week_cos  \
# item_id timestamp
# 0       1979-01-31              1.0     8.660254e-01             -0.5
#         1979-02-28              1.0     8.660254e-01             -0.5
#         1979-03-31              1.0    -8.660254e-01              0.5
#         1979-04-30              1.0     0.000000e+00              1.0
#         1979-05-31              1.0     1.224647e-16             -1.0
#
#                     day_of_month_sin  day_of_month_cos  day_of_year_sin  \
# item_id timestamp
# 0       1979-01-31          0.106293          0.994335         0.495009
#         1979-02-28         -0.507666          0.861554         0.842101
#         1979-03-31          0.106293          0.994335         0.999404
#         1979-04-30         -0.106293          0.994335         0.885456
#         1979-05-31          0.106293          0.994335         0.524704
#
#                     day_of_year_cos  week_of_year_sin  week_of_year_cos  \
# item_id timestamp
# 0       1979-01-31         0.868888          0.473094          0.881012
#         1979-02-28         0.539320          0.833602          0.552365
#         1979-03-31         0.034516          0.995734          0.092268
#         1979-04-30        -0.464723          0.866025         -0.500000
#         1979-05-31        -0.851284          0.526432         -0.850217
#
#                     month_of_year_sin  month_of_year_cos
# item_id timestamp
# 0       1979-01-31           0.000000           1.000000
#         1979-02-28           0.540641           0.841254
#         1979-03-31           0.909632           0.415415
#         1979-04-30           0.989821          -0.142315
#         1979-05-31           0.755750          -0.654861

# %%
test_tsdf.head()
# Out:
#                     target  running_index  year  hour_of_day_sin  \
# item_id timestamp
# 0       1992-08-31     NaN            163  1992              0.0
#         1992-09-30     NaN            164  1992              0.0
#         1992-10-31     NaN            165  1992              0.0
#         1992-11-30     NaN            166  1992              0.0
#         1992-12-31     NaN            167  1992              0.0
#
#                     hour_of_day_cos  day_of_week_sin  day_of_week_cos  \
# item_id timestamp
# 0       1992-08-31              1.0     0.000000e+00              1.0
#         1992-09-30              1.0     8.660254e-01             -0.5
#         1992-10-31              1.0    -8.660254e-01              0.5
#         1992-11-30              1.0     0.000000e+00              1.0
#         1992-12-31              1.0     1.224647e-16             -1.0
#
#                     day_of_month_sin  day_of_month_cos  day_of_year_sin  \
# item_id timestamp
# 0       1992-08-31          0.106293          0.994335        -0.868888
#         1992-09-30         -0.106293          0.994335        -1.000000
#         1992-10-31          0.106293          0.994335        -0.860214
#         1992-11-30         -0.106293          0.994335        -0.495009
#         1992-12-31          0.106293          0.994335         0.017261
#
#                     day_of_year_cos  week_of_year_sin  week_of_year_cos  \
# item_id timestamp
# 0       1992-08-31    -4.950088e-01         -0.920906         -0.389786
#         1992-09-30    -1.836970e-16         -0.995734          0.092268
#         1992-10-31     5.099326e-01         -0.833602          0.552365
#         1992-11-30     8.688880e-01         -0.361242          0.932472
#         1992-12-31     9.998510e-01          0.122888          0.992421
#
#                     month_of_year_sin  month_of_year_cos
# item_id timestamp
# 0       1992-08-31      -7.557496e-01          -0.654861
#         1992-09-30      -9.898214e-01          -0.142315
#         1992-10-31      -9.096320e-01           0.415415
#         1992-11-30      -5.406408e-01           0.841254
#         1992-12-31      -1.133108e-15           1.000000

# %% [markdown]
# ## Prediction

# %% [markdown]
# Now, let's perform prediction.
#
# We provide two options, `TabPFNMode.LOCAL` and `TabPFNMode.CLIENT`, as the backend for TabPFN.
#
# - `TabPFNMode.LOCAL` uses your local machine to run TabPFN.
# - `TabPFNMode.CLIENT` uses TabPFN's inference service provided by [tabpfn-client](https://github.com/automl/tabpfn-client)
#
# For this demo, we'll use `TabPFNMode.CLIENT` to perform prediction. If you have not use the client before, you'll be prompted to create an account.
#
# Note: if your machine doesn't have a GPU, using `TabPFNMode.CLIENT` is recommended -- must faster 😉.

# %%
from tabpfn_time_series import TabPFNTimeSeriesPredictor, TabPFNMode

predictor = TabPFNTimeSeriesPredictor(
    tabpfn_mode=TabPFNMode.CLIENT,
)

pred = predictor.predict(train_tsdf, test_tsdf)
# Out:
#   Welcome Back! Found existing access token, reusing it for authentication.
#   Welcome Back! Found existing access token, reusing it for authentication.
#   Welcome Back! Found existing access token, reusing it for authentication.
# Processing: 100%|██████████| [00:01<00:00]
# Processing: 100%|██████████| [00:02<00:00]

# %% [markdown]
# ## Visualize the Results
#
# Let's visualize the forecasting results.
#
# Also, note that we provide both **point prediction** and **quantile prediction**, how amazing! 😄

# %%
from tabpfn_time_series.plot import plot_pred_and_actual_ts

plot_pred_and_actual_ts(
    train=train_tsdf,
    test=test_tsdf_ground_truth,
    pred=pred,
)

# %%
pred.head()
# Out:
#                          target          0.1          0.2          0.3  \
# item_id timestamp
# 0       1992-08-31  6611.764160  6161.928711  6321.200195  6431.415039
#         1992-09-30  4181.602539  3886.891113  3985.798340  4058.571533
#         1992-10-31  3078.717529  2833.759033  2917.905273  2978.101807
#         1992-11-30  1972.623535  1769.138672  1838.883667  1888.717407
#         1992-12-31  2365.048340  2118.352051  2211.384033  2272.715088
#
#                             0.4          0.5          0.6          0.7  \
# item_id timestamp
# 0       1992-08-31  6524.588867  6611.764160  6706.739746  6810.077148
#         1992-09-30  4121.998047  4181.602539  4242.763184  4316.346191
#         1992-10-31  3030.161865  3078.717529  3129.331543  3186.600098
#         1992-11-30  1931.353394  1972.623535  2012.964233  2059.179443
#         1992-12-31  2321.381104  2365.048340  2407.733398  2452.551270
#
#                             0.8          0.9
# item_id timestamp
# 0       1992-08-31  6940.304688  7141.232422
#         1992-09-30  4418.898926  4576.833984
#         1992-10-31  3258.703857  3367.546875
#         1992-11-30  2112.888428  2189.614746
#         1992-12-31  2503.283203  2573.158203

# %% [markdown]
# # Feedback
#
# Let us know what you think!
#
# Write us at Discord: https://discord.gg/qK7AaXPN or just simply create an issue on [GitHub](https://github.com/liam-sbhoo/tabpfn-time-series/tree/main).
#
# Thank you for trying out our method! 🎉
